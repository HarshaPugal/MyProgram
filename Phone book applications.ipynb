# %%
"""
Excersise number:10
Start date      :19/08/2023
End date        :19/08/2023
Description     :To  Create phone book application using dictionaries
"""
def phone_number_validate(Value):
    dig=0
    Value1=Value
    while(Value1>0):
        Value1=int(Value1/10)
        dig=dig+1
    if(dig==10):
        return 1
Phone_book={}    #Phone_book={'Name':Phone_number}
print("1.Add a phone number to your phonebook\n2.Delete a phone number from your phonebook")
print("3.Replace a phone number from your phonebook\n4.View your phonebook")
print("5.Exit\n\n")
while(True):
    choice=int(input("Enter (1 or 2 or 3 or 4 or 5) \n"))
    if(choice==1):
        key=input("Enter the name ")
        Value=int(input("Enter the phone number "))
        a=phone_number_validate(Value)
        if(a):
            Phone_book[key]=Value
            print("\nPhone number added...")
        else:
            print("Enter a valid 10 digit phone number")
            Value=int(input("Enter the phone number "))
            Phone_book[key]=Value
            print("\nPhone number added...")
    elif(choice==2):
        del_key=input("Enter the name whose phone number wanted to be deleted ")
        del Phone_book[del_key]
        print("\nPhone number deleted")
    elif(choice==3):
        key1=input("Enter the name whose phone number wanted to be replaced ")
        if(key1 in Phone_book):
            Value2=int(input("Enter the new number "))
            a=phone_number_validate(Value2)
            if(a):
                Phone_book[key1]=Value2
                print("\nPhone number replaced")
            else:
                print("Enter a valid 10 digit phone number")
                Value2=int(input("Enter the new number "))
                Phone_book[key1]=Value2
                print("\nPhone number replaced")
        else:
            print("There is no such a key...")
    elif(choice==4):
        print(Phone_book)
    else:
        break
# Out:
# 1.Add a phone number to your phonebook
# 2.Delete a phone number from your phonebook
# 3.Replace a phone number from your phonebook
# 4.View your phonebook
# 5.Exit
#
#
# Enter (1 or 2 or 3 or 4 or 5)
# 1
# Enter the name AAA
# Enter the phone number 123
# Enter a valid 10 digit phone number
# Enter the phone number 1234567891
#
# Phone number added...
# Enter (1 or 2 or 3 or 4 or 5)
# 1
# Enter the name BBB
# Enter the phone number 6767676767
#
# Phone number added...
# Enter (1 or 2 or 3 or 4 or 5)
# 1
# Enter the name CCC
# Enter the phone number 9867659874
#
# Phone number added...
# Enter (1 or 2 or 3 or 4 or 5)
# 4
# {'AAA': 1234567891, 'BBB': 6767676767, 'CCC': 9867659874}
# Enter (1 or 2 or 3 or 4 or 5)
# 2
# Enter the name whose phone number wanted to be deleted BBB
#
# Phone number deleted
# Enter (1 or 2 or 3 or 4 or 5)
# 4
# {'AAA': 1234567891, 'CCC': 9867659874}
# Enter (1 or 2 or 3 or 4 or 5)
# 3
# Enter the name whose phone number wanted to be replaced AAA
# ...
